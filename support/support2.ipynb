# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ds=pd.read_csv('student-mat.csv')

# %%
#Answer Q1

pd.set_option('display.max_columns',500)
ds.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
ds.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
ds.shape
# Out:
# (395, 33)

# %%
ds.ndim
# Out:
# 2

# %%
#Answer Q2
#Attributes = 33
#Dimension = 2

# %%
import numpy
x = pd.read_csv('student-mat.csv')
dalc = ds.iloc[:,-7].values
round(numpy.mean(dalc),2)
# Out:
# 1.48

# %%
import numpy
x = pd.read_csv('student-mat.csv')
walc = ds.iloc[:,-6].values
round(numpy.mean(walc),2)
# Out:
# 2.29

# %%
import numpy
x = pd.read_csv('student-mat.csv')
absense = ds.iloc[:,-4].values
round(numpy.mean(absense),2)
# Out:
# 5.71

# %%
#Answer Q3
#Dalc = 1.48
#Walc = 2.29
#absence day of = 5.71

# %%
numpy.amax(absense)
# Out:
# 75

# %%
numpy.amin(absense)
# Out:
# 0

# %%
#Answer Q4
#Max = 75
#min = 0

# %%
#Answer Q5
x=pd.read_csv('student-mat.csv')
x=ds.iloc[:,-4].values

plt.hist(x)
plt.title("Histogram Of Number of Absense")
plt.xlabel("Number")
plt.ylabel("Absense")
plt.show()

# %%
#Answer Q6
import matplotlib.pyplot as plt
x = absense
y = dalc
plt.scatter(x,y)
plt.title("Absense Vs Dalc")
plt.xlabel("Absense")
plt.ylabel("Dalc")
plt.show()

# %%
#Answer Q7
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.11190803],
#        [0.11190803, 1.        ]])

# %%
#Answer Q8
#1. Range of days for absence = 6 days
#2. Most and Least Frequent days for absence for students = 38 days
#3. Observation on the distribution of days for absence = Absence distribution showing that is about Average and not great issue.
#4. Is there a linear relationship between days for absence and DALC? = NO relation

# %%
# SECTION B
# Naive Bayes – Step 1:

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

ds=pd.read_csv('student-mat.csv')
x=ds.iloc[:,[2,19,26,27]].values
y=ds.iloc[:,[20]].values

print(x)
print(y)
# Out:
# [[18 'yes' 1 1]
#  [17 'no' 1 1]
#  [15 'yes' 2 3]
#  ...
#  [21 'no' 3 3]
#  [18 'no' 3 4]
#  [19 'yes' 3 3]]
# [['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['yes']
#  ['no']
#  ['yes']
# ...

# %%
#Naive Bayes – Step 5

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X = LabelEncoder()
x[:, 1] = labelencoder_X.fit_transform(x[:, 1])

# %%
#Naive Bayes – Step 6
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
#Naive Bayes – Step 7
from sklearn.preprocessing import StandardScaler
sc_x=StandardScaler()
x_train=sc_x.fit_transform(x_train)
x_test=sc_x.fit_transform(x_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#Naive Bayes – Step 8
from sklearn.naive_bayes import GaussianNB
classifier= GaussianNB()
classifier.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None)

# %%
#Naive Bayes – Step 9
y_pred=classifier.predict(x_test)

# %%
#Naive Bayes – Step 10
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[ 0  7]
#  [ 2 90]]

# %%
#Naive Bayes – Step 11
accuracy = (90/99)*100
print ('accuracy=',accuracy)
# Out:
# accuracy= 90.9090909090909

# %%
#Naive Bayes – Step 12
#Discuss = From the result it shows that most of students are agreed to have higher education

# %%
# SECTION C

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

ds=pd.read_csv('student-mat.csv')
x=ds.iloc[:,[30,31]].values
y=ds.iloc[:,32].values

print(x)
print(y)
# Out:
# [[ 5  6]
#  [ 5  5]
#  [ 7  8]
#  [15 14]
#  [ 6 10]
#  [15 15]
#  [12 12]
#  [ 6  5]
#  [16 18]
#  [14 15]
#  [10  8]
#  [10 12]
#  [14 14]
#  [10 10]
#  [14 16]
#  [14 14]
#  [13 14]
#  [ 8 10]
#  [ 6  5]
#  [ 8 10]
#  [13 14]
#  [12 15]
#  [15 15]
#  [13 13]
#  [10  9]
#  [ 6  9]
#  [12 12]
#  [15 16]
#  [11 11]
#  [10 12]
#  [ 9 11]
#  [17 16]
#  [17 16]
#  [ 8 10]
#  [12 14]
#  [ 8  7]
#  [15 16]
#  [15 16]
#  [12 12]
#  [14 13]
#  [ 7 10]
#  [12 12]
#  [19 18]
#  [ 8  8]
#  [10 10]
#  [ 8  8]
#  [11 12]
#  [19 19]
#  [15 15]
#  [ 7  7]
#  [12 13]
#  [11 13]
#  [11 11]
#  [ 8 10]
#  [10 13]
#  [ 8  9]
#  [14 15]
#  [14 15]
#  [ 9 10]
#  [15 16]
#  [10 11]
#  [10  8]
#  [ 8 10]
#  [10  9]
#  [10 10]
#  [16 15]
#  [13 13]
#  [ 7  7]
#  [ 8  9]
#  [16 16]
#  [13 15]
#  [10 10]
#  [ 8  6]
#  [12 12]
#  [11 12]
#  [ 9  9]
#  [11 11]
#  [11 11]
#  [ 8  8]
#  [ 5  5]
#  [10 12]
#  [11 10]
#  [ 7  6]
#  [15 15]
#  [ 9 10]
#  [ 7  9]
#  [ 8  7]
#  [13 14]
#  [11 10]
#  [ 8  6]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
Indep_v=LinearRegression()
Indep_v.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_predict=Indep_v.predict(x_test)
print(y_predict)
# Out:
# [14.1318838  10.71147752  9.41807351 15.42528781 16.25888606 12.00488153
#  12.83847979 10.55820894  8.27793809 15.42528781  7.29107125 11.69834436
#  10.71147752  7.13780267 15.11875063 14.1318838  12.53194262  9.41807351
#   8.58447526 15.11875063  5.99766724  4.02393356  6.15093583 14.96548205
#  11.85161295 16.25888606  9.41807351 19.67929233 -0.1440577  12.53194262
#  -1.06366921  7.29107125  7.44433984  5.0108004  13.14501696  9.87787927
#  12.53194262 18.53915691  8.27793809 11.85161295  3.87066498 18.69242549
#   7.44433984  8.12466951  9.5713421  -1.06366921 11.69834436  4.02393356
#  11.85161295  6.8312655   8.73774385 18.38588832 10.71147752  7.59760842
#  11.85161295  7.29107125  8.73774385 12.83847979 14.96548205 13.97861521
#  12.99174837 13.29828554 14.1318838  15.57855639  8.58447526 15.27201922
#  18.69242549 12.3114187   4.02393356  8.58447526  8.27793809 13.97861521
#   6.15093583  4.02393356  8.58447526  8.12466951 10.40494035 18.53915691
#   5.99766724]

# %%
plt.scatter(y_test,y_predict)
plt.show()

# %%
#Discuss = From the scater plot showing that result is quiet OK
